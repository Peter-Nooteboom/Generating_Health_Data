# %%
from google.colab import drive
drive.mount('/content/drive')
directory = '/content/drive/MyDrive/Data Projects/Data Generation/Files'

import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(f'{directory}/Original_Data.csv')

# %%
df.head(1)
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         35.1          11.8         4.65        6.3          310  25.4  33.6
#
#     MCV  AGE SEX SOURCE
# 0  75.5    1   F    out

# %%
#Reordering and Renaming
df = df[['SOURCE','SEX','AGE', 'HAEMATOCRIT',	'HAEMOGLOBINS',	'ERYTHROCYTE',	'LEUCOCYTE',	'THROMBOCYTE',	'MCH',	'MCHC',	'MCV']]
df = df.rename(columns={'SOURCE':'Next_Treatment_Type', 'SEX':'Sex', 'AGE':'Age', 'HAEMATOCRIT':'Hematocrit', 'HAEMOGLOBINS':'Hemoglobins', 'ERYTHROCYTE':'Erythrocyte', 'LEUCOCYTE':'Leucocyte', 'THROMBOCYTE':'Thrombocyte'})

# %%
df.head(1)
# Out:
#   Next_Treatment_Type Sex  Age  Hematocrit  Hemoglobins  Erythrocyte  \
# 0                 out   F    1        35.1         11.8         4.65
#
#    Leucocyte  Thrombocyte   MCH  MCHC   MCV
# 0        6.3          310  25.4  33.6  75.5

# %%
#Recoding Variables
df['Next_Treatment_Type'].replace('out', 'Outpatient', inplace=True)
df['Next_Treatment_Type'].replace('in', 'Inpatient', inplace=True)
df['Sex'].replace('M', 'Male', inplace=True)
df['Sex'].replace('F', 'Female', inplace=True)

# %%
df.head(5)
# Out:
#   Next_Treatment_Type     Sex  Age  Hematocrit  Hemoglobins  Erythrocyte  \
# 0          Outpatient  Female    1        35.1         11.8         4.65
# 1          Outpatient  Female    1        43.5         14.8         5.39
# 2          Outpatient  Female    1        33.5         11.3         4.74
# 3          Outpatient  Female    1        39.1         13.7         4.98
# 4          Outpatient    Male    1        30.9          9.9         4.23
#
#    Leucocyte  Thrombocyte   MCH  MCHC   MCV
# 0        6.3          310  25.4  33.6  75.5
# 1       12.7          334  27.5  34.0  80.7
# 2       13.2          305  23.8  33.7  70.7
# 3       10.5          366  27.5  35.0  78.5
# 4       22.1          333  23.4  32.0  73.0

# %%
#Saving Data File
df.to_csv(f'{directory}/EHR_Data.csv', index=False)
